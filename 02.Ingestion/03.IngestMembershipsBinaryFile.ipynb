-- %% [markdown]
-- #### QUERYING `MEMBERSHIPS.BINARY` FROM VOLUME
-- - CATALOG NAME: gizmo
-- - STORAGE ACCOUNT NAME: gizmoboxdevadls
-- - SCHEMA NAME: landing

-- %%
SELECT * FROM binaryFile.`/Volumes/gizmo/landing/operational_data/memberships/*/*.png`;

-- %% [markdown]
-- #### CREATE `MEMBERSHIPS_VW`
-- - CATALOG NAME: gizmo
-- - SCHEMA NAME: bronze
-- - VIEW NAME: memberships_vw

-- %%
CREATE OR REPLACE VIEW gizmo.bronze.memberships_vw
AS
SELECT * FROM binaryFile.`/Volumes/gizmo/landing/operational_data/memberships/*/*.png`;

-- %%
SELECT * FROM gizmo.bronze.memberships_vw;

-- %%
%python
dbutils.notebook.exit("MEMBERSHIPS HAS BEEN LOADED SUCCESSFULLY")
