-- %% [markdown]
-- #### DROP ALL THE SCHEMAS TOP PERFORM CLAENUP AND DO FULL LOAD
-- - GIZMO.landing
-- - GIZMO.audit
-- - GIZMO.gold
-- - GIZMO.silver
-- - GIZMO.bronze
-- - HIVE_METASTORE.BRONZE

-- %%
DROP SCHEMA IF EXISTS GIZMO.landing CASCADE;
DROP SCHEMA IF EXISTS GIZMO.audit CASCADE;
DROP SCHEMA IF EXISTS GIZMO.gold CASCADE;
DROP SCHEMA IF EXISTS GIZMO.silver CASCADE;
DROP SCHEMA IF EXISTS GIZMO.bronze CASCADE;
DROP SCHEMA IF EXISTS HIVE_METASTORE.BRONZE CASCADE;
