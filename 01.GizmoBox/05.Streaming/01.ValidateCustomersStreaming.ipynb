-- %%
-- DROP TABLE IF EXISTS GIZMO.BRONZE.CUSTOMERS_STREAMING;

-- %% [markdown]
-- ### VALIDATE `GIZMO.BRONZE.CUSTOMERS_STREAMING`

-- %%
SELECT * FROM GIZMO.BRONZE.CUSTOMERS_STREAMING;

-- %%
ALTER TABLE GIZMO.BRONZE.CUSTOMERS_STREAMING
CLUSTER BY (customer_id)

-- %%
SELECT DISTINCT file_name FROM GIZMO.BRONZE.CUSTOMERS_STREAMING;

-- %%
SELECT
file_name,
count(*) AS RECORD_CNT
FROM
GIZMO.BRONZE.CUSTOMERS_STREAMING
GROUP BY file_name
ORDER BY 1 ASC;
