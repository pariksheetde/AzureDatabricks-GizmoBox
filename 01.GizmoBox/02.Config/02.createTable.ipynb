# %%
spark.sql("""
CREATE TABLE GIZMO.BRONZE.AUDIT_LOGS (
  log_id STRING,
  run_id STRING,
  event_time DATE,
  event_type STRING,
  source_table STRING,
  target_table STRING,
  record_count BIGINT,
  status STRING,
  message STRING,
  user_name STRING,
  notebook_path STRING,
  pipeline_name STRING,
  load_start_time TIMESTAMP,
  load_end_time TIMESTAMP
)
COMMENT 'Logging table for data ingestion events and pipeline activity'
""")
